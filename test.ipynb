# %%
import paho.mqtt.client as mqtt
from random import uniform
import time
import datetime
from wonderwords import RandomSentence
 
client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.connect('192.168.0.180')

while True:
    r = int(uniform(0,255))
    g = int(uniform(0,255))
    b = int(uniform(0,255))

    s = RandomSentence()

    client.publish("desk-lights", '{"rgb_color":[' + str(r) + ',' + str(g) + ',' + str(b) +']}')

    print(datetime.datetime.now())
    time.sleep(5)
# Out:
# 2025-09-05 16:47:41.726461
# 2025-09-05 16:47:46.727614
# 2025-09-05 16:47:51.728130
# 2025-09-05 16:47:56.728488
# 2025-09-05 16:48:01.729212
# 2025-09-05 16:48:06.729678
# 2025-09-05 16:48:11.730580
# 2025-09-05 16:48:16.731366
# 2025-09-05 16:48:21.731780
# 2025-09-05 16:48:26.732835
# 2025-09-05 16:48:31.733253
# 2025-09-05 16:48:36.734107
# 2025-09-05 16:48:41.734829
# 2025-09-05 16:48:46.735570
# 2025-09-05 16:48:51.735940
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 21
#      18 client.publish("speaker1", 0)
#      20 print(datetime.datetime.now())
# ---> 21 time.sleep(5)
#
# KeyboardInterrupt:
